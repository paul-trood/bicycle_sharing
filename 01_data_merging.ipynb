# %%
import pandas as pd
import os
import glob

# %% [markdown]
# Three questions will guide the future marketing program:
# 1. How do annual members and casual riders use Cyclistic bikes differently?
# 2. Why would casual riders buy Cyclistic annual memberships?
# 3. How can Cyclistic use digital media to influence casual riders to become members?

# %%
path = r"...2020" # use your path
all_files = glob.glob(os.path.join(path, "*.csv"))     # advisable to use os.path.join as this makes concatenation OS independent

list = []
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    list.append(df)

# Read csv files for each one in the file path
#df_from_each_file = (pd.read_csv(f) for f in all_files)

# Concatenate dataframes
#concatenated_df   = pd.concat(df_from_each_file, ignore_index=True)

# %%
list
# Out:
# [                ride_id rideable_type           started_at  \
#  0      A847FADBBC638E45   docked_bike  2020-04-26 17:45:14
#  1      5405B80E996FF60D   docked_bike  2020-04-17 17:08:54
#  2      5DD24A79A4E006F4   docked_bike  2020-04-01 17:54:13
#  3      2A59BBDF5CDBA725   docked_bike  2020-04-07 12:50:19
#  4      27AD306C119C6158   docked_bike  2020-04-18 10:22:59
#  ...                 ...           ...                  ...
#  84771  200E9CDFC5685AA0   docked_bike  2020-04-16 16:10:16
#  84772  F58A8F2ABCB5D95B   docked_bike  2020-04-30 17:56:12
#  84773  A3754693A80E4913   docked_bike  2020-04-24 19:57:33
#  84774  D610CABB67F7B744   docked_bike  2020-04-02 17:59:55
#  84775  79634521ABE4CF69   docked_bike  2020-04-04 01:31:27
#
#                    ended_at            start_station_name  start_station_id  \
#  0      2020-04-26 18:12:03                  Eckhart Park                86
#  1      2020-04-17 17:17:03     Drake Ave & Fullerton Ave               503
# ...

# %%
# Create a pandas dataframe
frame = pd.concat(list, axis = 0, ignore_index= True)

# %%
# Add year to differentiate between rows
frame["Year"] = 2020
frame
# Out:
#                   ride_id  rideable_type           started_at  \
# 0        A847FADBBC638E45    docked_bike  2020-04-26 17:45:14
# 1        5405B80E996FF60D    docked_bike  2020-04-17 17:08:54
# 2        5DD24A79A4E006F4    docked_bike  2020-04-01 17:54:13
# 3        2A59BBDF5CDBA725    docked_bike  2020-04-07 12:50:19
# 4        27AD306C119C6158    docked_bike  2020-04-18 10:22:59
# ...                   ...            ...                  ...
# 3114791  4631EE956BCEA738   classic_bike  2020-12-19 13:59:33
# 3114792  D17CBEDEA8DBDFF6  electric_bike  2020-12-20 15:48:41
# 3114793  447A6C67E9AF962E    docked_bike  2020-12-02 16:59:58
# 3114794  F558C17E95751C62  electric_bike  2020-12-20 18:06:52
# 3114795  E1888F4B274EEA12  electric_bike  2020-12-03 09:43:42
#
#                     ended_at            start_station_name start_station_id  \
# 0        2020-04-26 18:12:03                  Eckhart Park               86
# ...

# %%
path = r"...2021" # use your path
all_files = glob.glob(os.path.join(path, "*.csv"))     # advisable to use os.path.join as this makes concatenation OS independent

list = []
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    list.append(df)

# Create a pandas dataframe
frame_2 = pd.concat(list, axis = 0, ignore_index= True)

# %%
# Add year to differentiate between rows
frame_2["Year"] = 2021

# %%
path = r"...2022" # use your path
all_files = glob.glob(os.path.join(path, "*.csv"))     # advisable to use os.path.join as this makes concatenation OS independent

list = []
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    list.append(df)

# Create a pandas dataframe
frame_3 = pd.concat(list, axis = 0, ignore_index= True)

# %%
# Add year to differentiate between rows
frame_3["Year"] = 2022

# %%
path = r"...2023" # use your path
all_files = glob.glob(os.path.join(path, "*.csv"))     # advisable to use os.path.join as this makes concatenation OS independent

list = []
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    list.append(df)

# Create a pandas dataframe
frame_4 = pd.concat(list, axis = 0, ignore_index= True)

# %%
# Add year to differentiate between rows
frame_4["Year"] = 2023

# %%
# Concatenate all the dataframes into one large dataframe
data_frame = pd.concat([frame,frame_2,frame_3,frame_4], axis = 0)

# %%
#data_frame.to_csv("bicycle_sharing.csv",index=False)

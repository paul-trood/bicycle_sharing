# %% [markdown]
# United States Department of Transportation
# Regulatory Analysis
#
# Discover up to 5 main causes of accidents
# Resolutions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("US_Accidents_Dec21_updated.csv")

# %%
data.head()
# Out:
#     ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0  A-1         3  2016-02-08 00:37:08  2016-02-08 06:37:08  40.108910
# 1  A-2         2  2016-02-08 05:56:20  2016-02-08 11:56:20  39.865420
# 2  A-3         2  2016-02-08 06:15:39  2016-02-08 12:15:39  39.102660
# 3  A-4         2  2016-02-08 06:51:45  2016-02-08 12:51:45  41.062130
# 4  A-5         3  2016-02-08 07:53:43  2016-02-08 13:53:43  39.172393
#
#    Start_Lng    End_Lat    End_Lng  Distance(mi)  \
# 0 -83.092860  40.112060 -83.031870         3.230
# 1 -84.062800  39.865010 -84.048730         0.747
# 2 -84.524680  39.102090 -84.523960         0.055
# 3 -81.537840  41.062170 -81.535470         0.123
# 4 -84.492792  39.170476 -84.501798         0.500
#
#                                          Description  ...  Roundabout Station  \
# 0  Between Sawmill Rd/Exit 20 and OH-315/Olentang...  ...       False   False
# 1                 At OH-4/OH-235/Exit 41 - Accident.  ...       False   False
# ...

# %%
df = data.copy()

# %%
df.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2845342 entries, 0 to 2845341
# Data columns (total 47 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             object
#  3   End_Time               object
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Number                 float64
#  11  Street                 object
#  12  Side                   object
#  13  City                   object
#  14  County                 object
#  15  State                  object
#  16  Zipcode                object
#  17  Country                object
#  18  Timezone               object
#  19  Airport_Code           object
#  20  Weather_Timestamp      object
# ...

# %%
# Missing data calculated
missing_data = df.apply(pd.isnull).sum()/df.shape[0] * 100

# ONLY columns with missing data percentage greater than 0%
missing_data[missing_data > 0].sort_values(ascending=False)
# Out:
# Number                   61.290031
# Precipitation(in)        19.310789
# Wind_Chill(F)            16.505678
# Wind_Speed(mph)           5.550967
# Wind_Direction            2.592834
# Humidity(%)               2.568830
# Weather_Condition         2.482514
# Visibility(mi)            2.479350
# Temperature(F)            2.434646
# Pressure(in)              2.080593
# Weather_Timestamp         1.783125
# Airport_Code              0.335601
# Timezone                  0.128596
# Sunrise_Sunset            0.100761
# Civil_Twilight            0.100761
# Nautical_Twilight         0.100761
# Astronomical_Twilight     0.100761
# Zipcode                   0.046356
# City                      0.004815
# Street                    0.000070
# dtype: float64

# %% [markdown]
# ### Number
# The number column contains the most missing values at 61%.
# Number column indicates the street number that exists in the address field.

# %%
df["Number"].value_counts()
# Out:
# 1.0        10662
# 2.0         8747
# 101.0       6706
# 100.0       6187
# 198.0       2617
#            ...
# 42163.0        1
# 77683.0        1
# 36887.0        1
# 45105.0        1
# 68630.0        1
# Name: Number, Length: 46402, dtype: int64

# %%
df.corr()
# Out:
#                    Severity  Start_Lat  Start_Lng   End_Lat   End_Lng  \
# Severity           1.000000   0.089207   0.114063  0.089209  0.114064
# Start_Lat          0.089207   1.000000  -0.154965  0.999995 -0.154962
# Start_Lng          0.114063  -0.154965   1.000000 -0.154956  0.999999
# End_Lat            0.089209   0.999995  -0.154956  1.000000 -0.154953
# End_Lng            0.114064  -0.154962   0.999999 -0.154953  1.000000
# Distance(mi)       0.092140   0.071588   0.039861  0.071593  0.039830
# Number            -0.000689   0.101281  -0.170566  0.101270 -0.170563
# Temperature(F)    -0.045335  -0.475065   0.032159 -0.475058  0.032163
# Wind_Chill(F)     -0.097459  -0.505567   0.010849 -0.505561  0.010852
# Humidity(%)        0.037802   0.005876   0.170909  0.005869  0.170904
# Pressure(in)       0.043883  -0.234889   0.208828 -0.234896  0.208830
# Visibility(mi)     0.007371  -0.086538   0.029336 -0.086532  0.029338
# ...

# %%
pd.to_datetime(df["Start_Time"])
# Out:
# 0         2016-02-08 00:37:08
# 1         2016-02-08 05:56:20
# 2         2016-02-08 06:15:39
# 3         2016-02-08 06:51:45
# 4         2016-02-08 07:53:43
#                   ...
# 2845337   2019-08-23 18:03:25
# 2845338   2019-08-23 19:11:30
# 2845339   2019-08-23 19:00:21
# 2845340   2019-08-23 19:00:21
# 2845341   2019-08-23 18:52:06
# Name: Start_Time, Length: 2845342, dtype: datetime64[ns]

# %%
pd.to_datetime(df["End_Time"]).max()
# Out:
# Timestamp('2022-01-01 00:00:00')

# %%
df[["Start_Time","End_Time"]] = df[["Start_Time","End_Time"]].apply(pd.to_datetime)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2845342 entries, 0 to 2845341
# Data columns (total 47 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             datetime64[ns]
#  3   End_Time               datetime64[ns]
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Number                 float64
#  11  Street                 object
#  12  Side                   object
#  13  City                   object
#  14  County                 object
#  15  State                  object
#  16  Zipcode                object
#  17  Country                object
#  18  Timezone               object
#  19  Airport_Code           object
#  20  Weather_Timestamp      object
# ...

# %%
df["Severity"].value_counts()
# Out:
# 2    2532991
# 3     155105
# 4     131193
# 1      26053
# Name: Severity, dtype: int64

# %%
df = df.set_index("Start_Time")

# %%
df.resample("D").size().plot(figsize = (12,9))
# Out:
# <AxesSubplot:xlabel='Start_Time'>
